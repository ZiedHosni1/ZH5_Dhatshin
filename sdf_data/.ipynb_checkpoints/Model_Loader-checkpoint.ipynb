# %%
import os, json, random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import Descriptors, Draw, AllChem, DataStructs
import selfies
from tqdm import tqdm
from rdkit.Chem import PandasTools

# %%
# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
# Load QM9 CSV file (make sure qm9.csv is in the same folder)
df = pd.read_csv('qm9.csv')

# Ensure it has a column named 'smiles'
assert 'smiles' in df.columns, "CSV must have a 'smiles' column."

# Convert SMILES to RDKit Mol objects
PandasTools.AddMoleculeColumnToFrame(df, smilesCol='smiles')

# %%
def generate_unique_pairs(base_smiles_list, acid_smiles_list, max_pairs):
    seen = set()
    unique_pairs = []

    while len(unique_pairs) < max_pairs:
        b = random.choice(base_smiles_list)
        a = random.choice(acid_smiles_list)
        pair_key = (b, a)

        if pair_key not in seen:
            seen.add(pair_key)
            unique_pairs.append({'flp_smiles': f"{b}.{a}", 'type': 'inter'})

        # Optional: break early if we've exhausted all possible unique pairs
        if len(seen) >= len(base_smiles_list) * len(acid_smiles_list):
            break

    return unique_pairs

# %%
from rdkit import Chem
import pandas as pd
import random

def has_carbon_oxygen(mol):
    """Returns True if the molecule has at least one C and one O."""
    if mol is None:
        return False
    carbon = oxygen = 0
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() == 6:
            carbon += 1
        elif atom.GetAtomicNum() == 8:
            oxygen += 1
    return carbon >= 1 and oxygen >= 1

def is_lewis_base(mol):
    """Checks if molecule has a Lewis base site (N or P with lone pair)."""
    if mol is None or not has_carbon_oxygen(mol):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() in [7, 15]:  # N, P
            if atom.GetTotalDegree() >= 1 and atom.GetFormalCharge() <= 0:
                return True
    return False

def is_lewis_acid(mol):
    """Checks if molecule has a Lewis acid site (Boron, carbonyl C, or cation)."""
    if mol is None or not has_carbon_oxygen(mol):
        return False
    for atom in mol.GetAtoms():
        num = atom.GetAtomicNum()
        if num == 5 and atom.GetTotalDegree() <= 3:
            return True  # Boron
        if num == 6:
            neighbors = [nbr.GetAtomicNum() for nbr in atom.GetNeighbors()]
            if atom.GetHybridization() == Chem.HybridizationType.SP2 and 8 in neighbors:
                return True  # C=O carbon
        if atom.GetFormalCharge() > 0:
            return True  # Positively charged site
    return False

def is_intramolecular_flp(mol):
    """Returns True if molecule has both base and acid sites (intramolecular FLP)."""
    return is_lewis_base(mol) and is_lewis_acid(mol)

def extract_all_flps(df, max_pairs=None):
    """
    Extracts both intramolecular FLPs and intermolecular FLP pairs (carbon + oxygen required).

    Args:
        df (pd.DataFrame): QM9 DataFrame with 'ROMol' and 'smiles' columns.
        max_pairs (int, optional): Max number of intermolecular pairs to generate.

    Returns:
        pd.DataFrame: Combined FLP candidates with a 'type' column: 'intra' or 'inter'.
    """
    print("🔎 Filtering intramolecular FLPs...")
    intra_df = df[df['ROMol'].apply(is_intramolecular_flp)].copy()
    intra_df['flp_smiles'] = intra_df['smiles']
    intra_df['type'] = 'intra'

    print(f"✅ Found {len(intra_df)} intramolecular FLPs.")

    print("🔎 Filtering Lewis bases and acids for intermolecular FLPs...")
    bases_df = df[df['ROMol'].apply(is_lewis_base)].copy()
    acids_df = df[df['ROMol'].apply(is_lewis_acid)].copy()

    print(f"✅ Found {len(bases_df)} bases and {len(acids_df)} acids for pairing.")

    # Build intermolecular pairs
    inter_data = []
    if not bases_df.empty and not acids_df.empty:
        base_smiles = bases_df['smiles'].tolist()
        acid_smiles = acids_df['smiles'].tolist()
        if max_pairs:
            seen = set()
            while len(inter_data) < max_pairs:
                b = random.choice(base_smiles)
                a = random.choice(acid_smiles)
                key = (b, a)
                if key not in seen:
                    seen.add(key)
                    inter_data.append({'flp_smiles': f"{b}.{a}", 'type': 'inter'})

                if len(seen) >= len(base_smiles) * len(acid_smiles):
                    break  # all unique pairs exhausted

        else:
            seen = set()
            for b in base_smiles:
                for a in acid_smiles:
                    pair_key = (b, a)
                    if pair_key not in seen:
                        seen.add(pair_key)
                        inter_data.append({'flp_smiles': f"{b}.{a}", 'type': 'inter'})

    inter_df = pd.DataFrame(inter_data)

    print(f"✅ Generated {len(inter_df)} intermolecular FLP pairs.")

    # Combine both
    combined_df = pd.concat([intra_df[['flp_smiles', 'type']], inter_df], ignore_index=True)
    print(f"🔗 Total FLP candidates: {len(combined_df)}")

    return combined_df

# Example use:
print("Extracting all FLP candidates (intra + inter)...")
flp_all_df = extract_all_flps(df, max_pairs=70000)
print(flp_all_df.head())
# Out:
# Extracting all FLP candidates (intra + inter)...
# 🔎 Filtering intramolecular FLPs...
# ✅ Found 48699 intramolecular FLPs.
# 🔎 Filtering Lewis bases and acids for intermolecular FLPs...
# ✅ Found 67048 bases and 66805 acids for pairing.
# ✅ Generated 70000 intermolecular FLP pairs.
# 🔗 Total FLP candidates: 118699
#   flp_smiles   type
# 0     C(=O)N  intra
# 1    CC(=O)N  intra
# 2  C(=O)(N)N  intra
# 3   C(=O)C#N  intra
# 4      CNC=O  intra

# %%
class MolecularSELFIESDataset(Dataset):
    def __init__(self, smiles_list):
        self.smiles = smiles_list

        # Convert each SMILES to its tokenized SELFIES representation
        self.selfies_tokens_list = [self.smiles_to_selfies_tokens(smi) for smi in self.smiles]

        # Build vocabulary from all tokens (reserve index 0 for padding)
        all_tokens = [token for tokens in self.selfies_tokens_list for token in tokens]
        unique_tokens = sorted(set(all_tokens))
        self.token_to_idx = {token: idx + 1 for idx, token in enumerate(unique_tokens)}
        self.idx_to_token = {idx: token for token, idx in self.token_to_idx.items()}

        # Determine maximum sequence length for padding
        self.max_seq_len = max(len(tokens) for tokens in self.selfies_tokens_list)
        self.vocab_size = len(self.token_to_idx) + 1  # +1 for padding

        # Convert token sequences to fixed-length one-hot encoded vectors (flattened)
        self.encoded_data = []
        for tokens in self.selfies_tokens_list:
            token_indices = [self.token_to_idx[token] for token in tokens]
            padded = token_indices + [0] * (self.max_seq_len - len(token_indices))
            one_hot = np.eye(self.vocab_size)[padded]
            one_hot_flat = one_hot.flatten()
            self.encoded_data.append(one_hot_flat)

    def smiles_to_selfies_tokens(self, smiles):
        """Convert SMILES to SELFIES tokens"""
        try:
            selfies_str = selfies.encoder(smiles)
            tokens = list(selfies.split_selfies(selfies_str))
            return tokens
        except Exception:
            return []

    def __len__(self):
        return len(self.encoded_data)

    def __getitem__(self, idx):
        return torch.tensor(self.encoded_data[idx], dtype=torch.float32)


# Extract SMILES list and create the dataset and dataloader
# ✅ NEW: Use the 'flp_smiles' column (includes both intra & inter)
smiles_list = flp_all_df['flp_smiles'].dropna().tolist()

dataset = MolecularSELFIESDataset(smiles_list)
data_loader = DataLoader(dataset, batch_size=64, shuffle=True)

print(f"✅ Dataset successfully loaded with {len(dataset)} molecules for training.")
print(f"Vocabulary size: {dataset.vocab_size}, Sequence length: {dataset.max_seq_len}")

# Data dimension: each molecule is represented as a flattened vector
data_dim = dataset.max_seq_len * dataset.vocab_size
# Out:
# ✅ Dataset successfully loaded with 118699 molecules for training.
# Vocabulary size: 30, Sequence length: 41

# %%
latent_dim = 128

class Generator(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, output_dim),
            nn.Tanh()
        )
    def forward(self, z):
        return self.model(z)
    
class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )
    def forward(self, x):
        return self.model(x)

# %%
# --------------------
# Reconstructing Molecular Representations
# --------------------
def reconstruct_selfies(gen_output, max_seq_len, vocab_size, idx_to_token):
    """
    Convert a GAN-generated flattened vector into a SELFIES string.
    
    Args:
        gen_output (np.array): Flattened output vector from the generator.
        max_seq_len (int): Maximum sequence length used in the dataset.
        vocab_size (int): Vocabulary size used in one-hot encoding.
        idx_to_token (dict): Mapping from indices to SELFIES tokens.
    
    Returns:
        str: Reconstructed SELFIES string.
    """
    # Reshape the output vector into [max_seq_len, vocab_size]
    reshaped = gen_output.reshape(max_seq_len, vocab_size)
    # Discretize: choose the token with maximum value in each position
    token_indices = np.argmax(reshaped, axis=1)
    # Remove padding tokens (assumed index 0)
    token_indices = [idx for idx in token_indices if idx != 0]
    # Map indices back to tokens
    tokens = [idx_to_token.get(idx, '') for idx in token_indices]
    selfies_str = "".join(tokens)
    return selfies_str

# %%
# Set up
device = torch.device("cpu")
output_dir = "output"
checkpoint_path = os.path.join(output_dir, "checkpoint.pth")
metrics_path = os.path.join(output_dir, "training_metrics.csv")

# Reconstruct models with correct dimensions
latent_dim = 128
G = Generator(latent_dim, data_dim).to(device)
D = Discriminator(data_dim).to(device)

# Load checkpoint
checkpoint = torch.load(checkpoint_path, map_location=device)
G.load_state_dict(checkpoint["G"])
D.load_state_dict(checkpoint["D"])
print(f"✅ Loaded checkpoint from epoch {checkpoint['epoch']}")

# Load metrics
metrics = pd.read_csv(metrics_path)
print("Last 5 epochs of generator loss:")
print(metrics.tail(5))

# Optional: Plot
plt.figure()
plt.plot(metrics["epoch"], metrics["loss_G"], label="Generator")
plt.plot(metrics["epoch"], metrics["loss_D"], label="Discriminator")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("WGAN Training Losses")
plt.show()
# Out:
# ✅ Loaded checkpoint from epoch 778
# Last 5 epochs of generator loss:
#      epoch    loss_G    loss_D
# 774    774 -0.837128 -1.532362
# 775    775 -0.934287 -1.488787
# 776    776 -1.006284 -1.381557
# 777    777 -0.836800 -1.375829
# 778    778 -0.776570 -1.360528

# %%
n_samples = 100  # Number of molecules to generate
G.eval()  # Set the generator to evaluation mode

generated_smiles_list = set()

with torch.no_grad():
    # Generate a batch of latent vectors
    z = torch.randn(n_samples, latent_dim)
    # Generate samples from the generator
    gen_samples = G(z).detach().cpu().numpy()
    
    # For each generated sample, reconstruct the SELFIES and convert to SMILES
    for gen_sample in gen_samples:
        selfies_str = reconstruct_selfies(gen_sample, dataset.max_seq_len, dataset.vocab_size, dataset.idx_to_token)
        smiles_str = selfies.decoder(selfies_str)
        if smiles_str != "":
            generated_smiles_list.add(smiles_str)

# Print all generated SMILES
for i, smi in enumerate(generated_smiles_list, 1):
    print(f"Molecule {i}: {smi}")
# Out:
# Molecule 1: CCOC1(C=O)CN1O
# Molecule 2: CCC=CCOC=NC
# Molecule 3: C=1N[NH1]C=1.OCCCCOCC2C=C2
# Molecule 4: C1C=NN=CC1=O.O=CCC=CC=C=O
# Molecule 5: CCC1(CC)NO1
# Molecule 6: CN(CN)COC(N)=O
# Molecule 7: CC1CCC(N1)CN
# Molecule 8: CC1C2CN2C1C=O.CC=NCC3CC3C(O4)C4
# Molecule 9: C1=C([NH1]C(=N1)N)CCO
# Molecule 10: C=CN=CCCC(C)NCOCO.N=COCCNCCO
# Molecule 11: NC#CC=CC(C)C.CC=O
# Molecule 12: CCC(OC#N)C
# Molecule 13: CC1NC1C(=O)CC=O
# Molecule 14: CCC1N=CC=NC1N
# Molecule 15: CC(C1)N1CN.CC=O
# Molecule 16: CCC1CCN(N)C1=O
# Molecule 17: O=C1CC(O)N=C2OC12.O=CNN=NC=C
# Molecule 18: C1(O)=C=NC1CO2.COC(=O)C(=N)C2
# Molecule 19: CC(=O)CCC(C)C=O
# Molecule 20: OCC(F)C(C)N=C=O
# Molecule 21: C1CCN=C(C)NCC.CCCC1CCOCCO
# Molecule 22: CN(C=O)C1=CC=NO1.CC(C)(CCCN)C=O
# Molecule 23: O=C1CCC1CCOC
# Molecule 24: CC1=NC=CCO1
# Molecule 25: O=COC1CC1CC.CCOC23CCC2OC=NO3
# Molecule 26: CN=COCN1CN1
# Molecule 27: OC=CNCC=O
# Molecule 28: CC1OC2CC2NC1=N
# Molecule 29: N=CC1CC1C(C)CN.C=C
# Molecule 30: CN(C#N)CNCC(=O)C#N.CCC(C)N=COC=O
# Molecule 31: CC(C)C1OOC1=O.COCCCCC2OC2OO
# Molecule 32: CNCC1NC1C
# Molecule 33: C1NC12COCO2
# Molecule 34: CNC=NC1CCCCCO1
# Molecule 35: C=C1OC1C=NCCOC.CCCN=CC(=N2)C2C
# Molecule 36: C=CN=C(O)OCC=O
# Molecule 37: C1OC1COCNC=O
# Molecule 38: C1NC(CC=O)N1
# Molecule 39: COC(C1=C=N)(NO1)N
# Molecule 40: C#CC1=CN=C(O1)OO
# Molecule 41: CC=C(OCNC1N)N1
# Molecule 42: C1OC=NCC1=O.CCCCC=O
# Molecule 43: O1CC2C3C2CCC3=O.O=C1NNO
# Molecule 44: ON1C=C(C(=N1)OC)O.CCCCCCCC=O
# Molecule 45: CC1CC1C=O.CCCOC2=NC2
# Molecule 46: CCOC(CC=O)N
# Molecule 47: OC1(C=O)CC1C.C.CC(O)CCCCC=O
# Molecule 48: CC12CC1=CCC2C=N3.C4=CCOC43C=O
# Molecule 49: CC1CC1C2CC=CO2.C3C(OC3)CCC4NC4
# Molecule 50: CC(=O)NC(=O)CC[NH3+1].C[NH2+1]CC1CN=CC1O
# Molecule 51: CCC1CN1CC#N.N=CCCOOCOC
# Molecule 52: CC=COCOC(=N)C1C=C1
# Molecule 53: NCC1C[NH1]1.OC(CCCC(=O)C)=O
# Molecule 54: COCCCCOC(=O)NO
# Molecule 55: OC1C(F)C=N1.NCCCCC(O2)C2
# Molecule 56: C=C1COC2CNC2C1
# Molecule 57: CC1CNCCC1
# Molecule 58: CCC(=N)C1=CO1.O=CCCCN
# Molecule 59: O=C1CNC(=O)C1
# Molecule 60: C=1C(=CON=1)COC=O
# Molecule 61: CCCOC(=O)OC=O
# Molecule 62: O=COCC.CC=O
# Molecule 63: CC(O)C(C)=NC=C
# Molecule 64: N1=CCN2C3=NCC3NN1C2.OC4NOCCC4=C
# Molecule 65: CCC1NN(CN1)OC.CCC2C=COC(=O)N2C=O
# Molecule 66: CCCCCC(=N)C
# Molecule 67: O=C=NCCOCC=N.C
# Molecule 68: C=C(CN)CC=O
# Molecule 69: CCC(O)C(C1)CC1O.CNC(C)NCOC
# Molecule 70: C1NCC=CC1=N.CC2.C2.C(=O)C#CC
# Molecule 71: N1=C(C2)N2.O=CCC(=O)NO1
# Molecule 72: O=CCCCNC
# Molecule 73: C12C(CO1)CNC3CN3.O=C(O)CCC2=N
# Molecule 74: C1=C2[NH1]C=C1C2=O
# Molecule 75: CC1C[C-1](N)C1NC=O
# Molecule 76: CC(=O)C1=NOC1NC
# Molecule 77: C=C(CN)C[NH1]O
# Molecule 78: C1=O.CCC=C=[NH1+1]1
# Molecule 79: N=COC=NNCC
# Molecule 80: C1CC1COC=O.CC2C34CC3=C24
# Molecule 81: N1=COCCC2N1OC2.CC=C3OCCC3=O
# Molecule 82: CC(C=O)CCOC
# Molecule 83: CCC1OC(=N)N1.O=COCCOC2CC2
# Molecule 84: CCOC(C)=O
# Molecule 85: N=CC1CCCCC1=O.C=C(O2)OC2CN
# Molecule 86: OCCC1CC(=O)N1
# Molecule 87: C=CNOON1CN1C=O.C2C3=CCC2(O)OC3=O
# Molecule 88: CCN(O)CCO
# Molecule 89: CC(C=NC#N)C=O.O=CCOC=NC(C1)C1
# Molecule 90: O=C1CCC=COC1=N.CC2CCC(=O)C2N=N
# Molecule 91: CC1OC(CC1)C2CO2
# Molecule 92: O=C1C2NCCCOC12
# Molecule 93: CCCCN(NCC)O.CCCC1COC(=O)C1
# Molecule 94: CCCCC(C=O)=O.COO
# Molecule 95: CCC1=NOCNCO1.CCCC(=O)CC=O
# Molecule 96: O=C1N2CCCC21CO
# Molecule 97: O=CNCCC1=C=C1.CC=O
# Molecule 98: O=CCN=CC(CC)O.C=O
# Molecule 99: CNC=CC=O.CC1C=CCC1C2C=C2
# Molecule 100: CC=CC(CN)NO

# %%
from rdkit import Chem

def validate_smiles(smiles_str):
    """
    Validate a SMILES string using RDKit.
    
    Args:
        smiles_str (str): The SMILES string to validate.
        
    Returns:
        bool: True if the SMILES is valid, False otherwise.
    """
    try:
        # Convert the SMILES string into an RDKit molecule
        mol = Chem.MolFromSmiles(smiles_str)
        if mol is None:
            return False
        
        # Optional: sanitize the molecule to catch any additional issues
        Chem.SanitizeMol(mol)
        return True
    except Exception as e:
        # If any exception occurs, the SMILES is considered invalid
        return False
for i, smi in enumerate(generated_smiles_list, 1):
    print(smi)
    if validate_smiles(smi):
        print("The generated SMILES is valid!")
    else:
        print("The generated SMILES is invalid.")
# Out:
# CCOC1(C=O)CN1O
# The generated SMILES is valid!
# CCC=CCOC=NC
# The generated SMILES is valid!
# C=1N[NH1]C=1.OCCCCOCC2C=C2
# The generated SMILES is valid!
# C1C=NN=CC1=O.O=CCC=CC=C=O
# The generated SMILES is valid!
# CCC1(CC)NO1
# The generated SMILES is valid!
# CN(CN)COC(N)=O
# The generated SMILES is valid!
# CC1CCC(N1)CN
# The generated SMILES is valid!
# CC1C2CN2C1C=O.CC=NCC3CC3C(O4)C4
# The generated SMILES is valid!
# C1=C([NH1]C(=N1)N)CCO
# The generated SMILES is valid!
# C=CN=CCCC(C)NCOCO.N=COCCNCCO
# The generated SMILES is valid!
# NC#CC=CC(C)C.CC=O
# The generated SMILES is valid!
# CCC(OC#N)C
# The generated SMILES is valid!
# CC1NC1C(=O)CC=O
# The generated SMILES is valid!
# CCC1N=CC=NC1N
# The generated SMILES is valid!
# CC(C1)N1CN.CC=O
# The generated SMILES is valid!
# CCC1CCN(N)C1=O
# The generated SMILES is valid!
# O=C1CC(O)N=C2OC12.O=CNN=NC=C
# The generated SMILES is valid!
# C1(O)=C=NC1CO2.COC(=O)C(=N)C2
# The generated SMILES is valid!
# CC(=O)CCC(C)C=O
# The generated SMILES is valid!
# OCC(F)C(C)N=C=O
# The generated SMILES is valid!
# C1CCN=C(C)NCC.CCCC1CCOCCO
# The generated SMILES is valid!
# CN(C=O)C1=CC=NO1.CC(C)(CCCN)C=O
# The generated SMILES is valid!
# O=C1CCC1CCOC
# The generated SMILES is valid!
# CC1=NC=CCO1
# The generated SMILES is valid!
# O=COC1CC1CC.CCOC23CCC2OC=NO3
# The generated SMILES is valid!
# CN=COCN1CN1
# The generated SMILES is valid!
# OC=CNCC=O
# The generated SMILES is valid!
# CC1OC2CC2NC1=N
# The generated SMILES is valid!
# N=CC1CC1C(C)CN.C=C
# The generated SMILES is valid!
# CN(C#N)CNCC(=O)C#N.CCC(C)N=COC=O
# The generated SMILES is valid!
# CC(C)C1OOC1=O.COCCCCC2OC2OO
# The generated SMILES is valid!
# CNCC1NC1C
# The generated SMILES is valid!
# C1NC12COCO2
# The generated SMILES is valid!
# CNC=NC1CCCCCO1
# The generated SMILES is valid!
# C=C1OC1C=NCCOC.CCCN=CC(=N2)C2C
# The generated SMILES is valid!
# C=CN=C(O)OCC=O
# The generated SMILES is valid!
# C1OC1COCNC=O
# The generated SMILES is valid!
# C1NC(CC=O)N1
# The generated SMILES is valid!
# COC(C1=C=N)(NO1)N
# The generated SMILES is valid!
# C#CC1=CN=C(O1)OO
# The generated SMILES is valid!
# CC=C(OCNC1N)N1
# The generated SMILES is valid!
# C1OC=NCC1=O.CCCCC=O
# The generated SMILES is valid!
# O1CC2C3C2CCC3=O.O=C1NNO
# The generated SMILES is valid!
# ON1C=C(C(=N1)OC)O.CCCCCCCC=O
# The generated SMILES is valid!
# CC1CC1C=O.CCCOC2=NC2
# The generated SMILES is valid!
# CCOC(CC=O)N
# The generated SMILES is valid!
# OC1(C=O)CC1C.C.CC(O)CCCCC=O
# The generated SMILES is valid!
# CC12CC1=CCC2C=N3.C4=CCOC43C=O
# The generated SMILES is valid!
# CC1CC1C2CC=CO2.C3C(OC3)CCC4NC4
# The generated SMILES is valid!
# CC(=O)NC(=O)CC[NH3+1].C[NH2+1]CC1CN=CC1O
# The generated SMILES is valid!
# CCC1CN1CC#N.N=CCCOOCOC
# The generated SMILES is valid!
# CC=COCOC(=N)C1C=C1
# The generated SMILES is valid!
# NCC1C[NH1]1.OC(CCCC(=O)C)=O
# The generated SMILES is valid!
# COCCCCOC(=O)NO
# The generated SMILES is valid!
# OC1C(F)C=N1.NCCCCC(O2)C2
# The generated SMILES is valid!
# C=C1COC2CNC2C1
# The generated SMILES is valid!
# CC1CNCCC1
# The generated SMILES is valid!
# CCC(=N)C1=CO1.O=CCCCN
# The generated SMILES is valid!
# O=C1CNC(=O)C1
# The generated SMILES is valid!
# C=1C(=CON=1)COC=O
# The generated SMILES is valid!
# CCCOC(=O)OC=O
# The generated SMILES is valid!
# O=COCC.CC=O
# The generated SMILES is valid!
# CC(O)C(C)=NC=C
# The generated SMILES is valid!
# N1=CCN2C3=NCC3NN1C2.OC4NOCCC4=C
# The generated SMILES is valid!
# CCC1NN(CN1)OC.CCC2C=COC(=O)N2C=O
# The generated SMILES is valid!
# CCCCCC(=N)C
# The generated SMILES is valid!
# O=C=NCCOCC=N.C
# The generated SMILES is valid!
# C=C(CN)CC=O
# The generated SMILES is valid!
# CCC(O)C(C1)CC1O.CNC(C)NCOC
# The generated SMILES is valid!
# C1NCC=CC1=N.CC2.C2.C(=O)C#CC
# The generated SMILES is valid!
# N1=C(C2)N2.O=CCC(=O)NO1
# The generated SMILES is valid!
# O=CCCCNC
# The generated SMILES is valid!
# C12C(CO1)CNC3CN3.O=C(O)CCC2=N
# The generated SMILES is valid!
# C1=C2[NH1]C=C1C2=O
# The generated SMILES is valid!
# CC1C[C-1](N)C1NC=O
# The generated SMILES is valid!
# CC(=O)C1=NOC1NC
# The generated SMILES is valid!
# C=C(CN)C[NH1]O
# The generated SMILES is valid!
# C1=O.CCC=C=[NH1+1]1
# The generated SMILES is valid!
# N=COC=NNCC
# The generated SMILES is valid!
# C1CC1COC=O.CC2C34CC3=C24
# The generated SMILES is valid!
# N1=COCCC2N1OC2.CC=C3OCCC3=O
# The generated SMILES is valid!
# CC(C=O)CCOC
# The generated SMILES is valid!
# CCC1OC(=N)N1.O=COCCOC2CC2
# The generated SMILES is valid!
# CCOC(C)=O
# The generated SMILES is valid!
# N=CC1CCCCC1=O.C=C(O2)OC2CN
# The generated SMILES is valid!
# OCCC1CC(=O)N1
# The generated SMILES is valid!
# C=CNOON1CN1C=O.C2C3=CCC2(O)OC3=O
# The generated SMILES is valid!
# CCN(O)CCO
# The generated SMILES is valid!
# CC(C=NC#N)C=O.O=CCOC=NC(C1)C1
# The generated SMILES is valid!
# O=C1CCC=COC1=N.CC2CCC(=O)C2N=N
# The generated SMILES is valid!
# CC1OC(CC1)C2CO2
# The generated SMILES is valid!
# O=C1C2NCCCOC12
# The generated SMILES is valid!
# CCCCN(NCC)O.CCCC1COC(=O)C1
# The generated SMILES is valid!
# CCCCC(C=O)=O.COO
# The generated SMILES is valid!
# CCC1=NOCNCO1.CCCC(=O)CC=O
# The generated SMILES is valid!
# O=C1N2CCCC21CO
# The generated SMILES is valid!
# O=CNCCC1=C=C1.CC=O
# The generated SMILES is valid!
# O=CCN=CC(CC)O.C=O
# The generated SMILES is valid!
# CNC=CC=O.CC1C=CCC1C2C=C2
# The generated SMILES is valid!
# CC=CC(CN)NO
# The generated SMILES is valid!

# %%
from rdkit import Chem
from rdkit.Chem import Draw
import matplotlib.pyplot as plt

def visualize_smiles(smiles_str):
    """
    Convert a SMILES string to an RDKit molecule and visualize it.
    
    Args:
        smiles_str (str): The SMILES string to visualize.
    """
    # Convert SMILES to an RDKit molecule
    mol = Chem.MolFromSmiles(smiles_str)
    if mol is None:
        print("Invalid SMILES string.")
        return
    
    # Option 1: Using MolToImage to create a PIL image and display it with matplotlib
    img = Draw.MolToImage(mol, size=(300, 300))
    plt.imshow(img)
    plt.axis('off')
    plt.title("Molecular Graph")
    plt.show()

for i, smi in enumerate(generated_smiles_list, 1):
    print(smi)
    visualize_smiles(smi)
# Out:
# CCOC1(C=O)CN1O
# CCC=CCOC=NC
# C=1N[NH1]C=1.OCCCCOCC2C=C2
# C1C=NN=CC1=O.O=CCC=CC=C=O
# CCC1(CC)NO1
# CN(CN)COC(N)=O
# CC1CCC(N1)CN
# CC1C2CN2C1C=O.CC=NCC3CC3C(O4)C4
# C1=C([NH1]C(=N1)N)CCO
# C=CN=CCCC(C)NCOCO.N=COCCNCCO
# NC#CC=CC(C)C.CC=O
# CCC(OC#N)C
# CC1NC1C(=O)CC=O
# CCC1N=CC=NC1N
# CC(C1)N1CN.CC=O
# CCC1CCN(N)C1=O
# O=C1CC(O)N=C2OC12.O=CNN=NC=C
# C1(O)=C=NC1CO2.COC(=O)C(=N)C2
# CC(=O)CCC(C)C=O
# OCC(F)C(C)N=C=O
# C1CCN=C(C)NCC.CCCC1CCOCCO
# CN(C=O)C1=CC=NO1.CC(C)(CCCN)C=O
# O=C1CCC1CCOC
# CC1=NC=CCO1
# O=COC1CC1CC.CCOC23CCC2OC=NO3
# CN=COCN1CN1
# OC=CNCC=O
# CC1OC2CC2NC1=N
# N=CC1CC1C(C)CN.C=C
# CN(C#N)CNCC(=O)C#N.CCC(C)N=COC=O
# CC(C)C1OOC1=O.COCCCCC2OC2OO
# CNCC1NC1C
# C1NC12COCO2
# CNC=NC1CCCCCO1
# C=C1OC1C=NCCOC.CCCN=CC(=N2)C2C
# C=CN=C(O)OCC=O
# C1OC1COCNC=O
# C1NC(CC=O)N1
# COC(C1=C=N)(NO1)N
# C#CC1=CN=C(O1)OO
# CC=C(OCNC1N)N1
# C1OC=NCC1=O.CCCCC=O
# O1CC2C3C2CCC3=O.O=C1NNO
# ON1C=C(C(=N1)OC)O.CCCCCCCC=O
# CC1CC1C=O.CCCOC2=NC2
# CCOC(CC=O)N
# OC1(C=O)CC1C.C.CC(O)CCCCC=O
# CC12CC1=CCC2C=N3.C4=CCOC43C=O
# CC1CC1C2CC=CO2.C3C(OC3)CCC4NC4
# CC(=O)NC(=O)CC[NH3+1].C[NH2+1]CC1CN=CC1O
# CCC1CN1CC#N.N=CCCOOCOC
# CC=COCOC(=N)C1C=C1
# NCC1C[NH1]1.OC(CCCC(=O)C)=O
# COCCCCOC(=O)NO
# OC1C(F)C=N1.NCCCCC(O2)C2
# C=C1COC2CNC2C1
# CC1CNCCC1
# CCC(=N)C1=CO1.O=CCCCN
# O=C1CNC(=O)C1
# C=1C(=CON=1)COC=O
# CCCOC(=O)OC=O
# O=COCC.CC=O
# CC(O)C(C)=NC=C
# N1=CCN2C3=NCC3NN1C2.OC4NOCCC4=C
# CCC1NN(CN1)OC.CCC2C=COC(=O)N2C=O
# CCCCCC(=N)C
# O=C=NCCOCC=N.C
# C=C(CN)CC=O
# CCC(O)C(C1)CC1O.CNC(C)NCOC
# C1NCC=CC1=N.CC2.C2.C(=O)C#CC
# N1=C(C2)N2.O=CCC(=O)NO1
# O=CCCCNC
# C12C(CO1)CNC3CN3.O=C(O)CCC2=N
# C1=C2[NH1]C=C1C2=O
# CC1C[C-1](N)C1NC=O
# CC(=O)C1=NOC1NC
# C=C(CN)C[NH1]O
# C1=O.CCC=C=[NH1+1]1
# N=COC=NNCC
# C1CC1COC=O.CC2C34CC3=C24
# N1=COCCC2N1OC2.CC=C3OCCC3=O
# CC(C=O)CCOC
# CCC1OC(=N)N1.O=COCCOC2CC2
# CCOC(C)=O
# N=CC1CCCCC1=O.C=C(O2)OC2CN
# OCCC1CC(=O)N1
# C=CNOON1CN1C=O.C2C3=CCC2(O)OC3=O
# CCN(O)CCO
# CC(C=NC#N)C=O.O=CCOC=NC(C1)C1
# O=C1CCC=COC1=N.CC2CCC(=O)C2N=N
# CC1OC(CC1)C2CO2
# O=C1C2NCCCOC12
# CCCCN(NCC)O.CCCC1COC(=O)C1
# CCCCC(C=O)=O.COO
# CCC1=NOCNCO1.CCCC(=O)CC=O
# O=C1N2CCCC21CO
# O=CNCCC1=C=C1.CC=O
# O=CCN=CC(CC)O.C=O
# CNC=CC=O.CC1C=CCC1C2C=C2
# CC=CC(CN)NO

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs

def measure_uniqueness(smiles_list):
    """
    Calculates the fraction of unique SMILES.
    
    Args:
        smiles_list (list of str): A list of SMILES strings.
    
    Returns:
        float: The fraction of unique SMILES in the list.
    """
    # Filter out invalid SMILES (None after parsing)
    valid_smiles = []
    for smi in smiles_list:
        mol = Chem.MolFromSmiles(smi)
        if mol is not None:
            valid_smiles.append(Chem.MolToSmiles(mol, isomericSmiles=True))
    # Convert to set to remove duplicates
    unique_smiles = set(valid_smiles)
    if len(valid_smiles) == 0:
        return 0.0
    return len(unique_smiles) / len(valid_smiles)

def measure_diversity(smiles_list, radius=2, nBits=1024):
    """
    Computes the average pairwise Tanimoto distance (1 - similarity) among molecules.
    A higher average distance indicates higher diversity.
    
    Args:
        smiles_list (list of str): A list of SMILES strings.
        radius (int): Radius parameter for Morgan fingerprint.
        nBits (int): Size of the fingerprint bit vector.
    
    Returns:
        float: Average pairwise Tanimoto distance (1 - similarity).
    """
    # Generate fingerprints for all valid SMILES
    fps = []
    for smi in smiles_list:
        mol = Chem.MolFromSmiles(smi)
        if mol is not None:
            fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=nBits)
            fps.append(fp)
    
    if len(fps) < 2:
        # Not enough molecules to compare
        return 0.0
    
    # Compute pairwise Tanimoto similarities
    similarities = []
    for i in range(len(fps)):
        for j in range(i + 1, len(fps)):
            sim = DataStructs.TanimotoSimilarity(fps[i], fps[j])
            similarities.append(sim)
    
    # Convert similarity to distance = 1 - similarity
    distances = [1 - sim for sim in similarities]
    
    # Return the average distance
    return np.mean(distances)



uniqueness = measure_uniqueness(generated_smiles_list)
diversity = measure_diversity(generated_smiles_list, radius=2, nBits=1024)

print(f"Uniqueness: {uniqueness:.2f}")
print(f"Average Pairwise Tanimoto Distance: {diversity:.3f}")
# Out:
# Uniqueness: 1.00
# Average Pairwise Tanimoto Distance: 0.907
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator
# [10:00:12] DEPRECATION WARNING: please use MorganGenerator

# %%
gen_df = pd.DataFrame(generated_smiles_list, columns=['smiles'])

# %%
gen_df
# Out:
#                         smiles
# 0               CCOC1(C=O)CN1O
# 1                  CCC=CCOC=NC
# 2   C=1N[NH1]C=1.OCCCCOCC2C=C2
# 3    C1C=NN=CC1=O.O=CCC=CC=C=O
# 4                  CCC1(CC)NO1
# ..                         ...
# 95              O=C1N2CCCC21CO
# 96          O=CNCCC1=C=C1.CC=O
# 97           O=CCN=CC(CC)O.C=O
# 98    CNC=CC=O.CC1C=CCC1C2C=C2
# 99                 CC=CC(CN)NO
#
# [100 rows x 1 columns]

# %%
from rdkit.Chem.rdPartialCharges import ComputeGasteigerCharges

def extract_flp_features(flp_smiles):
    features = {
        'charge_diff': None,
        'tpsa': None,
        'rotatable_bonds': None,
        'num_rings': None
    }

    try:
        if '.' in flp_smiles:
            # Intermolecular FLP pair: split into base + acid
            base_smiles, acid_smiles = flp_smiles.split('.')
            base_mol = Chem.MolFromSmiles(base_smiles)
            acid_mol = Chem.MolFromSmiles(acid_smiles)
            if base_mol is None or acid_mol is None:
                return features

            # Add Hs + charges
            base = Chem.AddHs(base_mol)
            acid = Chem.AddHs(acid_mol)
            ComputeGasteigerCharges(base)
            ComputeGasteigerCharges(acid)

            base_charges = [float(atom.GetProp('_GasteigerCharge')) for atom in base.GetAtoms()]
            acid_charges = [float(atom.GetProp('_GasteigerCharge')) for atom in acid.GetAtoms()]
            features['charge_diff'] = abs(max(base_charges) - min(acid_charges))

            # Sum properties
            features['tpsa'] = Descriptors.TPSA(base) + Descriptors.TPSA(acid)
            features['rotatable_bonds'] = Descriptors.NumRotatableBonds(base) + Descriptors.NumRotatableBonds(acid)
            features['num_rings'] = base.GetRingInfo().NumRings() + acid.GetRingInfo().NumRings()

        else:
            # Intramolecular FLP: single molecule
            mol = Chem.MolFromSmiles(flp_smiles)
            if mol is None:
                return features

            mol = Chem.AddHs(mol)
            ComputeGasteigerCharges(mol)
            charges = [float(atom.GetProp('_GasteigerCharge')) for atom in mol.GetAtoms()]
            # Charge diff: max minus min in same molecule
            features['charge_diff'] = abs(max(charges) - min(charges))

            # Single-molecule descriptors
            features['tpsa'] = Descriptors.TPSA(mol)
            features['rotatable_bonds'] = Descriptors.NumRotatableBonds(mol)
            features['num_rings'] = mol.GetRingInfo().NumRings()

    except Exception as e:
        print("⚠️ Feature extraction failed for:", flp_smiles, "| Error:", e)

    return features

# %%
gen_feature_dicts = gen_df["smiles"].apply(extract_flp_features)
gen_features_df = pd.DataFrame(gen_feature_dicts.tolist())
# Out:
# ⚠️ Feature extraction failed for: OC1(C=O)CC1C.C.CC(O)CCCCC=O | Error: too many values to unpack (expected 2)
# ⚠️ Feature extraction failed for: C1NCC=CC1=N.CC2.C2.C(=O)C#CC | Error: too many values to unpack (expected 2)
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'C1(O)=C=NC1CO2'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'COC(=O)C(=N)C2'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'C1CCN=C(C)NCC'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'CCCC1CCOCCO'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'O1CC2C3C2CCC3=O'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'O=C1NNO'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'CC12CC1=CCC2C=N3'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'C4=CCOC43C=O'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'N1=C(C2)N2'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'O=CCC(=O)NO1'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'C12C(CO1)CNC3CN3'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)CCC2=N'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'C1=O'
# [10:02:07] SMILES Parse Error: unclosed ring for input: 'CCC=C=[NH1+1]1'

# %%
gen_features_df
# Out:
#     charge_diff   tpsa  rotatable_bonds  num_rings
# 0      0.588658  49.54              5.0        1.0
# 1      0.648552  21.59              5.0        0.0
# 2      0.583354  61.04              7.0        2.0
# 3      0.483645  75.93              3.0        1.0
# 4      0.435586  34.47              4.0        1.0
# ..          ...    ...              ...        ...
# 95     0.644785  40.31              2.0        2.0
# 96     0.510349  46.17              4.0        1.0
# 97     0.518083  66.73              6.0        0.0
# 98     0.247043  29.10              5.0        2.0
# 99     0.566070  58.28              6.0        0.0
#
# [100 rows x 4 columns]

# %%
flp_all_features_df = pd.concat([gen_df, gen_features_df], axis=1)

# %%
flp_all_features_df
# Out:
#                         smiles  charge_diff   tpsa  rotatable_bonds  \
# 0               CCOC1(C=O)CN1O     0.588658  49.54              5.0
# 1                  CCC=CCOC=NC     0.648552  21.59              5.0
# 2   C=1N[NH1]C=1.OCCCCOCC2C=C2     0.583354  61.04              7.0
# 3    C1C=NN=CC1=O.O=CCC=CC=C=O     0.483645  75.93              3.0
# 4                  CCC1(CC)NO1     0.435586  34.47              4.0
# ..                         ...          ...    ...              ...
# 95              O=C1N2CCCC21CO     0.644785  40.31              2.0
# 96          O=CNCCC1=C=C1.CC=O     0.510349  46.17              4.0
# 97           O=CCN=CC(CC)O.C=O     0.518083  66.73              6.0
# 98    CNC=CC=O.CC1C=CCC1C2C=C2     0.247043  29.10              5.0
# 99                 CC=CC(CN)NO     0.566070  58.28              6.0
#
#     num_rings  score
# 0         1.0      3
# 1         0.0      1
# 2         2.0      2
# 3         1.0      2
# 4         1.0      3
# ..        ...    ...
# 95        2.0      3
# 96        1.0      3
# 97        0.0      2
# 98        2.0      2
# 99        0.0      2
#
# [100 rows x 6 columns]

# %%
flp_all_features_df.to_csv("output.csv", index=False)

# %%
# Rank molecules based on criteria:
# 1. High charge_diff
# 2. Moderate TPSA (30–70 ideal)
# 3. Moderate rotatable bonds (2–6 ideal)
# 4. Prefer 1–2 rings

# Create a scoring system based on the above
def score_molecule(row):
    score = 0
    if row['tpsa'] >= 30 and row['tpsa'] <= 70:
        score += 1
    if row['rotatable_bonds'] >= 2 and row['rotatable_bonds'] <= 6:
        score += 1
    if row['num_rings'] >= 1 and row['num_rings'] <= 2:
        score += 1
    return score

# Apply scoring and sort
flp_all_features_df['score'] = flp_all_features_df.apply(score_molecule, axis=1)
df_sorted = flp_all_features_df.sort_values(by=['score', 'charge_diff'], ascending=[False, False])

# Select top candidates
best = df_sorted.loc[df_sorted["score"] >= 3 ]
top_candidates = best.reset_index(drop=True)

# %%
top_candidates[['smiles', 'charge_diff', 'tpsa', 'rotatable_bonds', 'num_rings', 'score']]
# Out:
#                   smiles  charge_diff   tpsa  rotatable_bonds  num_rings  \
# 0       C#CC1=CN=C(O1)OO     0.825154  55.49              2.0        1.0
# 1      C=1C(=CON=1)COC=O     0.755757  52.33              2.0        1.0
# 2     CC=COCOC(=N)C1C=C1     0.696308  42.31              5.0        1.0
# 3     CC1C[C-1](N)C1NC=O     0.683147  55.12              3.0        1.0
# 4         CC=C(OCNC1N)N1     0.649355  59.31              2.0        1.0
# 5         O=C1N2CCCC21CO     0.644785  40.31              2.0        2.0
# 6            CN=COCN1CN1     0.637489  46.54              3.0        1.0
# 7          OCCC1CC(=O)N1     0.618089  49.33              3.0        1.0
# 8   CC1CC1C=O.CCCOC2=NC2     0.602499  38.66              5.0        2.0
# 9        CC(=O)C1=NOC1NC     0.596709  50.69              4.0        1.0
# 10        CCOC1(C=O)CN1O     0.588658  49.54              5.0        1.0
# 11          C1OC1COCNC=O     0.579011  50.86              4.0        1.0
# 12        CNC=NC1CCCCCO1     0.540028  33.62              2.0        1.0
# 13        CCC1CCN(N)C1=O     0.519591  46.33              3.0        1.0
# 14    O=CNCCC1=C=C1.CC=O     0.510349  46.17              4.0        1.0
# 15   C1OC=NCC1=O.CCCCC=O     0.494520  55.73              4.0        1.0
# 16       CC1NC1C(=O)CC=O     0.460792  56.08              4.0        1.0
# 17          CC1CCC(N1)CN     0.451714  38.05              3.0        1.0
# 18             CNCC1NC1C     0.441065  33.97              4.0        1.0
# 19           CCC1(CC)NO1     0.435586  34.47              4.0        1.0
# 20         CCC1N=CC=NC1N     0.428496  50.74              3.0        1.0
# 21          C1NC(CC=O)N1     0.428343  41.13              2.0        1.0
# 22       CC(C1)N1CN.CC=O     0.423361  46.10              4.0        1.0
# 23    N=CC1CC1C(C)CN.C=C     0.292821  49.87              5.0        1.0
#
#     score
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
# 5       3
# 6       3
# 7       3
# 8       3
# 9       3
# 10      3
# 11      3
# 12      3
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      3
# 19      3
# 20      3
# 21      3
# 22      3
# 23      3
